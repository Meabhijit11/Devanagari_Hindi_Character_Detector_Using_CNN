# %%
import cv2
import tensorflow as tf
from keras.preprocessing import image
from PIL import Image
import numpy as np

# %%
model = tf.keras.models.load_model(r'Hindi_Model')

# %%
def determine_character(res):
    print(res)
    if res == 1:
        print('prediction : क')     
        
    elif res == 2:
        print('prediction : ख')
        
    elif res == 3:
        print('prediction : ग')
    
    elif res == 4:
        print('prediction : घ')
        
    elif res == 5:
        print('prediction : ङ')
        
    elif res == 6:
        print('prediction : च')

    elif res == 7:
        print('prediction : छ')
        
    elif res == 8:
        print('prediction : ज')
        
    elif res == 9:
        print('prediction : झ')

    elif res == 10:
        print('prediction : ञ')
        
    elif res == 11:
        print('prediction : ट')
        
    elif res == 12:
        print('prediction : ठ')
        
    elif res == 13:
        print('prediction : ड')
        
    elif res == 14:
        print('prediction : ढ')

    elif res == 15:
        print('prediction : ण')
        
    elif res == 16:
        print('prediction : त')

    elif res == 17:
        print('prediction : थ')

    elif res == 18:
        print('prediction : द')

    elif res == 19:
        print('prediction : ध')

    elif res == 20:
        print('prediction : न')
        
    elif res == 21:
        print('prediction : प')

    elif res == 22:
        print('prediction : फ')

    elif res == 23:
        print('prediction : ब')

    elif res == 24:
        print('prediction : भ')
        
    elif res == 25:
        print('prediction : म')
        
    elif res == 26:
        print('prediction : य')

    elif res == 27:
        print('prediction : र')

    elif res == 28:
        print('prediction : ल')
        
    elif res == 29:
        print('prediction : व')
        
    elif res == 30:
        print('prediction : श')
        
    elif res == 31:
        print('prediction : ष')
        
    elif res == 32:
        print('prediction : स')
        
    elif res == 33:
        print('prediction : ह')

    elif res == 34:
        print('prediction : क्ष')

    elif res == 35:
        print('prediction : त्र')

    elif res == 36:
        print('prediction : ज्ञ')
        
    elif res == 37:
        print('prediction : ०')      
        
    elif res == 38:
        print('prediction : १')

    elif res == 39:
        print('prediction : २')

    elif res == 40:
        print('prediction : ३')

    elif res == 41:
        print('prediction : ४')               
        
    elif res == 42:
        print('prediction : ५')
       
    elif res == 43:
        print('prediction : ६')
        
    elif res == 44:
        print('prediction : ७')
        
    elif res == 45:
        print('prediction : ८')

    elif res == 46:
        print('prediction : ९')

# %%
# model = tf.keras.models.load_model(r'BrainTumor_model')

from matplotlib.pyplot import imshow
img = Image.open(r"C:\Users\meabh\Deep Learning\Hindi\DevanagariHandwrittenCharacterDataset\Train\character_12_thaa\355.png")
x = np.array(img.resize((32,32)))
x = x.reshape(1,32,32,1)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(determine_character(classification)))
# Out:
# 12
# prediction : ठ
# None
